# %%
import dotenv
dotenv.load_dotenv(override=True)

import os
import uuid
import json
from typing import List, Union, Dict
from pydantic import BaseModel, Field
from pydantic_core import to_jsonable_python
from pydantic_ai import Agent, RunContext
from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider
from pydantic_ai.mcp import MCPServerStdio
from pydantic_ai.messages import (
    ToolReturnPart, 
    TextPart, 
    ModelResponse, 
    ModelMessage, 
    ModelMessagesTypeAdapter, 
    UserPromptPart,
)
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
# Initialize Openai-like model
model = OpenAIModel(
    'gemma3:27b-it-qat',
    provider=OpenAIProvider(
        base_url=os.getenv("AGENT_BASE_URL"),
        api_key=os.getenv("AGENT_API_KEY")
    ),
)

# %%
# MCP server
rag_mcp_command = "uv run python /agent_framework_demo/demo/1_rag_server.py stdio" #TODO: 要使用絕對路徑

rag_mcp_server = MCPServerStdio(
    command = rag_mcp_command.split(" ")[0],
    args = rag_mcp_command.split(" ")[1:],
    env = {
        "OPENAI_BASE_URL": os.getenv("OPENAI_BASE_URL"),
        "OPENAI_API_KEY": os.getenv("OPENAI_API_KEY")
    },
    timeout=60,  # 增加 timeout
)

# %%
# structured output
from pydantic import BaseModel, Field

class Reference(BaseModel):
    score: float
    #relevant: bool
    text: str

class ReferenceWithCriticism(BaseModel):
    relevant: bool
    text: str
    
class Criticism(BaseModel):
    passages: List[ReferenceWithCriticism]
    explanation: str
    sufficient: bool

class RAGFormat(BaseModel):
    reference: List[str] = Field(
        default_factory=list,
        description="List of passages text used to generate the answer."
    )
    final_answer: str

# %%
# Agent initialization
assistant_agent = Agent(
    name="assistant_agent",
    model = model,
    instructions = (
        "You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \n"
        "Behavior Rules: \n"
        "1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n"
        "2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n"
        "3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.\n"
    ),
    output_type=Union[RAGFormat, str],

)
seeker_agent = Agent(
    name="seeker_agent",
    model=model,
    instructions=(
        "You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \n"
        "Behavior Rules: \n"
        "1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n"
        "2. Return all the retrieval results with Reference format.\n"
    ),
    mcp_servers=[rag_mcp_server],
    output_type=List[Reference],
)

critic_agent = Agent(
    name="critic_agent",
    model=model, 
    instructions=(
        "You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \n"
        "Behavior Rules: \n"
        "1. Critically evaluate whether the retrieved passages are relevant to the user's query.\n"
        "2. Critically evaluate whether the retrieved passages are sufficient to answer the user's query.\n"
    ),
    output_type=Criticism,
)
generator_agent = Agent(
    name="generator_agent",
    model=model,
    instructions=(
        "You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \n"
        "Behavior Rules: \n"
        "1. Generate a final answer based on the retrieved passages.\n"
        "2. If the retrieved passages are insufficient, ask follow-up questions to gather more information.\n"
    ),
    output_type=RAGFormat,
)

# %%
# Memory Management

class MemoryManager(BaseModel):
    user_id: str = Field(
        default= f"user_{uuid.uuid4().hex[:16]}", 
        description = "User identification"
    )
    session_id: str = Field(
        default= f"{uuid.uuid4().hex[:16]}", 
        description = "Session identification"
    )
    max_turns: int = Field(
        default= 30, 
        description = "Max turns of conversation"
    )
    save_path: str = Field(
        default=os.getcwd(),
        description="Chat conversation history saving directory",
    )
    main_agent: str = Field(
        default="assistant_agent",
        description="Name of main agent",
    )
    message_history: Union[Dict[str, list[ModelMessage]], None] = Field(
        default={},
        description="Chat conversation history",
    )

    def convert_tool_role_into_assistant(self, massage_history):
        if isinstance(massage_history[-1].parts[0], ToolReturnPart):
            raw_assistant_message = massage_history[-2]
            assistant_message = ModelResponse(
                parts=[
                    TextPart(
                        content = raw_assistant_message.parts[0].args,
                        part_kind = "text",
                    ),
                ],
                usage = raw_assistant_message.usage,
                model_name = raw_assistant_message.model_name,
                timestamp = raw_assistant_message.timestamp,
                kind = raw_assistant_message.kind,
                vendor_id = raw_assistant_message.vendor_id
                )
            return massage_history + [assistant_message]
        else:
            return massage_history
    
    def trim_history_by_max_turns(self, message_history):
        turn_start_index = {}
        num_turns = 0
        for idx, message in enumerate(message_history):
            try:
                if isinstance(message.parts[0], UserPromptPart):
                    turn_start_index[num_turns] = idx
                    num_turns += 1
            except:
                pass
        if self.max_turns > num_turns:
            return message_history
        else:
            return message_history[turn_start_index[num_turns-self.max_turns]:]
    
    def append_message(self, agent_name: str, new_messages: List[ModelMessage]) -> None:
        """
            Add new message to the conversation history of specific agent
        """
        new_messages_converted = self.convert_tool_role_into_assistant(new_messages)
        if agent_name in self.message_history.keys():
            self.message_history[agent_name].extend(new_messages_converted)
        else:
            self.message_history[agent_name] = new_messages_converted
    
    def get_history(self, agent_name: str) -> Union[list[ModelMessage], None]:
        if agent_name in self.message_history.keys():
            return self.trim_history_by_max_turns(self.message_history[agent_name])
        else:
            print(f"No history of {agent_name}...")
            return None
    
    def save_history(self):
        history_as_python_objects = to_jsonable_python(self.get_history("assistant_agent"))

        saving_dir = os.path.join(self.save_path, self.user_id)
        os.makedirs(saving_dir, exist_ok=True)
        with open(os.path.join(saving_dir, f"{self.session_id}.json"), "w") as f:
            json.dump(history_as_python_objects, f, indent=4, ensure_ascii=False)
    
    def clear_message(self) -> None:
        """
            Reset chat history
        """
        self.message_history.clear()
    
    def load_history_from_disk(self):
        chat_history_dir = os.path.join(self.save_path, self.user_id, f"{self.session_id}.json")
        with open(chat_history_dir, "r") as f:
            history_as_python_objects = json.load(f)
        self.message_history[self.main_agent] = ModelMessagesTypeAdapter.validate_python(history_as_python_objects)

# %%
# multi-turn conversation
async def multi_turn_conversation(start_agent: Agent, history_manager: MemoryManager):
    while True:
        user_input = input("You: ")
        print(f"You: {user_input}")

        if user_input == "exit":
            print("Agent: Goodbye!")
            return response

        response = await start_agent.run(
            user_prompt = user_input,
            deps = history_manager,
            message_history = history_manager.get_history(start_agent.name),
        )
        print(f"Agent: {response.output}")
        history_manager.append_message(
            agent_name=start_agent.name,
            new_messages=response.new_messages(),
        )

# %%
async def retrieve_info(history_manager: MemoryManager, query: str):
    """
        Retrieve relevant information based on the user query.
    """
    n_retries = 3
    async with seeker_agent.run_mcp_servers():
        for _ in range(n_retries):
            print("start seeker agent...")
            response = await seeker_agent.run(
                user_prompt = query,
                deps = history_manager,
            )
            history_manager.append_message(
                agent_name=seeker_agent.name,
                new_messages=response.new_messages(),
            )
            try:
                if isinstance(response.output[0], Reference):
                    print("seeker agent:", response.output)
                    #print(response.usage())
                    #print(response.new_messages())
                    return response.output
            except Exception as e:
                print(f"Error in seeker agent response: {e}")

async def get_passage_criticism(history_manager: MemoryManager, user_query: str, retrieved_passages: List[Reference]):
    """
        Get criticism for each retrieved passage.
    """
    input_text = (
        "The user's query and the retrieved passages are as follows:\n"
        f"## User Query: {user_query}\n"
        "## Retrieved Passages:\n"
        + "\n".join([f"[{i + 1}] {passage.text}" for i, passage in enumerate(retrieved_passages)])
    )
    n_retries = 3
    for _ in range(n_retries):
        response = await critic_agent.run(
            user_prompt=input_text,
            deps=history_manager,
        )
        history_manager.append_message(
            agent_name=critic_agent.name,
            new_messages=response.new_messages(),
        )
        if isinstance(response.output, Criticism):
            print("critic agent:", response.output)
            return response.output


async def generate_answer(history_manager: MemoryManager, user_query: str, passages_with_criticism: Criticism):
    """
        Generate final answer to the user query based on retrieved passages.
    """
    input_text = (
        "The user's query and the retrieved passages are as follows:\n"
        f"## User Query: {user_query}\n"
        "## Relevant Passages:\n"
        + "\n".join([f"[{i+1}] {passage.text}" for i, passage in enumerate(passages_with_criticism.passages) if passage.relevant])
    )
    n_retries = 3
    for _ in range(n_retries):
        response = await generator_agent.run(
            user_prompt=input_text,
            deps=history_manager,
        )
        history_manager.append_message(
            agent_name=generator_agent.name,
            new_messages=response.new_messages(),
        )
        if isinstance(response.output, RAGFormat):
            print("generator agent:", response.output)
            return response.output
    

@assistant_agent.tool()
async def rag(ctx: RunContext[MemoryManager], query: str) -> Union[RAGFormat ,Criticism, None]:
    """
        response the user query based on external knowledge
    """
    retrieved_passages = await retrieve_info(ctx.deps, query)
    critic_result = await get_passage_criticism(ctx.deps, ctx.prompt, retrieved_passages)
    if critic_result.sufficient:
        final_answer = await generate_answer(ctx.deps, ctx.prompt, critic_result)
        return final_answer
    else:
        print("Insufficient criticism from the critic agent.")
        return critic_result

# %%
async def main(history_manager: MemoryManager):
    response = await multi_turn_conversation(assistant_agent, history_manager)
    return response

# %%
history_manager = MemoryManager(
    user_id="user_1", 
    session_id="session_1",
    save_path=os.path.join(os.getcwd(), "pydanticai_storage")
)

result = await main(history_manager)
# Out:
# You: 我想要請假，有沒有什麼限制？
# No history of assistant_agent...
# start seeker agent...
# seeker agent: [Reference(score=0.7, text='此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。'), Reference(score=0.42953295, text='一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'), Reference(score=0.3, text='一、同仁因執行公務中受傷之病假，稱為公傷假。\n二、公傷假之醫療費用，以勞工保險及公司加保之團保負擔之，其餘相關規定及補償辦法比照第八章災害傷病補償及撫卹之規定辦理。\n三、職業災害未認定前，勞工得先請普通傷病假；普通傷病假期滿，得申請留職停薪，如認定結果為職業災害，再以公傷病假處理。'), Reference(score=0.28747067, text='一、紀念日，勞動節日及中央主管機關規定應放假之日，是放假日。 \n二、相關日期依當年政府規定於每年開始時，公告同仁周知。\n三、主管或同仁個人因工作上的需要必須應用此放假日工作者，必須依照延長工作時間申請程序申請延長工作。\n四、申請延長工作時間作業必須在規定期限內完成。\n五、本延長工作時間之薪資按日工資再發一日。'), Reference(score=0.2645357, text='一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。')]
# critic agent: passages=[ReferenceWithCriticism(relevant=True, text='[5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \n\n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。')] explanation='這份文件提供了請假的方法和流程，以及不同天數的請假需要提前多久申請，以及主管的審批權限。雖然其他文件提到了病假等類型，但[5]最完整地回答了使用者關於請假限制的問題。' sufficient=True
# generator agent: reference=['[1] [5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n\n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。'] final_answer='根據公司規定，請假種類共有十四種，包含特休假、生日假等等。請假方式需要事先填寫請假單或口頭敘明理由經核定。請假天數不同，核准主管權限及事前天數也不同：\n\n*   0-5天：三天前，部門主管核准\n*   5-10天：一週前，處級主管核准\n*   超過10天：兩週前，業務/事業群總經理核准\n\n如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。'
# Agent: 好的，公司請假規定如下：
#
# 一、休假種類共有十四種，包含特休假、生日假等等。
# 二、請假方式需要事先填寫請假單或口頭敘明理由經核定。
# 三、請假天數不同，核准主管權限及事前天數也不同：
#
# * 0-5天：三天前，部門主管核准
# * 5-10天：一週前，處級主管核准
# * 超過10天：兩週前，業務/事業群總經理核准
#
# 四、如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。
#
# 請問您還有其他想了解的嗎？
# You: 我可以請幾天假？
# start seeker agent...
# seeker agent: [Reference(score=0.7, text='一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\n二、生日假於生日當月有效，棄權者不得再補休。\n三、生日假薪資照給。'), Reference(score=0.67383134, text='一、同仁本人生產前後，產假八週(含星期例假日)。\n二、同仁本人妊娠三個月以上流產者，給予產假四星期。(含星期例假日)\n三、妊娠二個月以上未滿三個月流產者，給予產假一星期。(含星期例假日，不給薪)\n四、妊娠未滿二個月流產者，給予產假五日。(含星期例假日，不給薪)\n五、第一項、第二項產假期間薪資，對已任職滿六個月以上同仁，薪資照給，未滿六個月者減半發給。'), Reference(score=0.48483455, text='一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'), Reference(score=0.37600818, text='一、公司原則上以星期日為例假日，星期六為休息日。\n二、例假日不得工作，但是若因天災、事變或突發事件，雇主認有繼續工作之必要時，得停止員工例假日、國定假日、特休期間之假期。但停止假期之工資，應加倍發給，並應於事後補假休息。\n前項停止員工假期，應於事後二十四小時內，詳述理由，報請當地主管機關核備。\n三、例假日工資照給。'), Reference(score=0.3007, text='一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。')]
# critic agent: passages=[ReferenceWithCriticism(relevant=True, text='一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\n二、生日假於生日當月有效，棄權者不得再補休。\n三、生日假薪資照給。'), ReferenceWithCriticism(relevant=True, text='一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。'), ReferenceWithCriticism(relevant=True, text='請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理')] explanation='根據提供的資料，員工到職當年可請一天生日假。此外，資料也列出了十四種休假種類，並說明了請假天數與核准權限。但要請幾天假，還需要根據具體的休假種類（例如特休假）以及員工的職位和請假原因而定。' sufficient=False
# Insufficient criticism from the critic agent.
# Agent: 您可以請的假天數取決於您要請哪一種假。根據公司規定：
#
# *   到職當年可以請一天生日假。
# *   其他休假種類，例如特休假、事假等等，請假天數沒有明確限制，但需要根據您的職位和請假原因，並事先向主管申請。具體天數需要依照公司請假規定（0-5天、5-10天、超過10天）來決定。
#
# 請問您想請哪一種假呢？這樣我才能更準確地告訴您。
# You: 我想請特休假
# start seeker agent...
# seeker agent: [Reference(score=0.7, text='此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。'), Reference(score=0.58001995, text='一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'), Reference(score=0.30635563, text='一、因公司業務需要，而指派特定人員參加考試檢定者，其費用由公司全額支付。\n二、因公司人才培育需求而鼓勵同仁自發性參與特定考試檢定者，依個別鼓勵辦法補助之。\n三、檢定考試完成之後，憑三聯式發票及考試成績單或檢定合格證書提出申請。'), Reference(score=0.3, text='一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\n年資\t特休假日數\n滿6個月~未滿1年\t3天\n滿1年~未滿2年\t7天\n滿2年~未滿3年\t10天\n滿3年~未滿5年\t14天\n滿5年~未滿10年\t15天\n滿10年以上\t每年加一天至30天止\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\n五、特休假期間薪資照給。'), Reference(score=0.28039062, text='同仁年資之採計方式規定如下:\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。')]
# critic agent: passages=[ReferenceWithCriticism(relevant=True, text='一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\n年資\t特休假日數\n滿6個月~未滿1年\t3天\n滿1年~未滿2年\t7天\n滿2年~未滿3年\t10天\n滿3年~未滿5年\t14天\n滿5年~未滿10年\t15天\n滿10年以上\t每年加一天至30天止\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\n五、特休假期間薪資照給。'), ReferenceWithCriticism(relevant=True, text='一、同仁年資之採計方式規定如下:\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。')] explanation='這兩段文字直接說明了公司的特休假規定，包括特休假天數的計算方式（依照年資）、未休餘假的處理方式（遞延或結算薪資），以及休假規劃的注意事項。這些資訊對於您請特休假非常有幫助。' sufficient=True
# generator agent: reference=['[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\t特休假日數 滿6個月~未滿1年\t3天 滿1年~未滿2年\t7天 滿2年~未滿3年\t10天 滿3年~未滿5年\t14天 滿5年~未滿10年\t15天 滿10年以上\t每年加一天至30天止 二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。', '[2] 一、同仁年資之採計方式規定如下: 一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。'] final_answer='您好，根據公司規定，特休假天數依您的年資而定：\n\n*   滿6個月~未滿1年：3天\n*   滿1年~未滿2年：7天\n*   滿2年~未滿3年：10天\n*   滿3年~未滿5年：14天\n*   滿5年~未滿10年：15天\n*   滿10年以上：每年加一天至30天止\n\n請您確認您的年資，以便計算您的特休天數。另外，請您在年度開始時做休假規劃，並與主管溝通，以確保工作順利進行。未休的特休假可以選擇遞延一年或結算薪資。'
# Agent: 您好，根據公司規定，特休假天數依您的年資而定：
#
# *   滿6個月~未滿1年：3天
# *   滿1年~未滿2年：7天
# *   滿2年~未滿3年：10天
# *   滿3年~未滿5年：14天
# *   滿5年~未滿10年：15天
# *   滿10年以上：每年加一天至30天止
#
# 請您確認您的年資，以便計算您的特休天數。另外，未休的特休假可以選擇遞延一年或結算薪資。
# You: 我目前工作滿一年了
# Agent: reference=['[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\\t特休假日數 滿6個月~未滿1年\\t3天 滿1年~未滿2年\\t7天 滿2年~未滿3年\\t10天 滿3年~未滿5年\\t14天 滿5年~未滿10年\\t15天 滿10年以上\\t每年加一天至30天止'] final_answer='您好，由於您目前工作滿一年了，根據公司規定，您今年可以請7天的特休假。'
# You: exit
# Agent: Goodbye!

# %%
history_manager.save_history()

# %%
history_manager.message_history
# Out:
# {'seeker_agent': [ModelRequest(parts=[UserPromptPart(content='請假規定', timestamp=datetime.datetime(2025, 7, 18, 9, 1, 35, 174590, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='retrieve_fps_rules_db', args='{"query":"請假規定"}', tool_call_id='ujgwlhUNx6INgh81hozB2bPlgRwy5AHc')], usage=Usage(requests=1, request_tokens=982, response_tokens=48, total_tokens=1030, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 1, 37, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-pJMK1ymBk9csNy9u14shkrg5EUmQlIjd'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='retrieve_fps_rules_db', content=[{'score': 0.7, 'text': '此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。'}, {'score': 0.42953295, 'text': '一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'}, {'score': 0.3, 'text': '一、同仁因執行公務中受傷之病假，稱為公傷假。\n二、公傷假之醫療費用，以勞工保險及公司加保之團保負擔之，其餘相關規定及補償辦法比照第八章災害傷病補償及撫卹之規定辦理。\n三、職業災害未認定前，勞工得先請普通傷病假；普通傷病假期滿，得申請留職停薪，如認定結果為職業災害，再以公傷病假處理。'}, {'score': 0.28747067, 'text': '一、紀念日，勞動節日及中央主管機關規定應放假之日，是放假日。 \n二、相關日期依當年政府規定於每年開始時，公告同仁周知。\n三、主管或同仁個人因工作上的需要必須應用此放假日工作者，必須依照延長工作時間申請程序申請延長工作。\n四、申請延長工作時間作業必須在規定期限內完成。\n五、本延長工作時間之薪資按日工資再發一日。'}, {'score': 0.2645357, 'text': '一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。'}], tool_call_id='ujgwlhUNx6INgh81hozB2bPlgRwy5AHc', timestamp=datetime.datetime(2025, 7, 18, 9, 1, 37, 837992, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"response":[{"score":0.7,"text":"此為依據勞動基準法所訂定的最基準工作時間。\\n一、每週工作時數不得超過四十小時。\\n二、每日工作時數為八小時。\\n三、每日工作時間為\\n08:30 開始上班\\n12:00 午休及午餐時間\\n13:00 下午工作時間開始\\n15:00 下午休息時間\\n15:15 繼續工作\\n17:30 下班\\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\\n1.\\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\\n2.\\t調整工作時間。\\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。"},{"score":0.42953295,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.3,"text":"一、同仁因執行公務中受傷之病假，稱為公傷假。\\n二、公傷假之醫療費用，以勞工保險及公司加保之團保負擔之，其餘相關規定及補償辦法比照第八章災害傷病補償及撫卹之規定辦理。\\n三、職業災害未認定前，勞工得先請普通傷病假；普通傷病假期滿，得申請留職停薪，如認定結果為職業災害，再以公傷病假處理。"},{"score":0.28747067,"text":"一、紀念日，勞動節日及中央主管機關規定應放假之日，是放假日。 \\n二、相關日期依當年政府規定於每年開始時，公告同仁周知。\\n三、主管或同仁個人因工作上的需要必須應用此放假日工作者，必須依照延長工作時間申請程序申請延長工作。\\n四、申請延長工作時間作業必須在規定期限內完成。\\n五、本延長工作時間之薪資按日工資再發一日。"},{"score":0.2645357,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \\n \\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}]}', tool_call_id='hbCUmVA6lqC4w6qh0o3dgc6hiZo5Vd9D')], usage=Usage(requests=1, request_tokens=2116, response_tokens=1072, total_tokens=3188, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 17, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-4NcpuJJt4qXAYQX1UJGD97KYtN6YwS7w'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='hbCUmVA6lqC4w6qh0o3dgc6hiZo5Vd9D', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 17, 508189, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"response":[{"score":0.7,"text":"此為依據勞動基準法所訂定的最基準工作時間。\\n一、每週工作時數不得超過四十小時。\\n二、每日工作時數為八小時。\\n三、每日工作時間為\\n08:30 開始上班\\n12:00 午休及午餐時間\\n13:00 下午工作時間開始\\n15:00 下午休息時間\\n15:15 繼續工作\\n17:30 下班\\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\\n1.\\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\\n2.\\t調整工作時間。\\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。"},{"score":0.42953295,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.3,"text":"一、同仁因執行公務中受傷之病假，稱為公傷假。\\n二、公傷假之醫療費用，以勞工保險及公司加保之團保負擔之，其餘相關規定及補償辦法比照第八章災害傷病補償及撫卹之規定辦理。\\n三、職業災害未認定前，勞工得先請普通傷病假；普通傷病假期滿，得申請留職停薪，如認定結果為職業災害，再以公傷病假處理。"},{"score":0.28747067,"text":"一、紀念日，勞動節日及中央主管機關規定應放假之日，是放假日。 \\n二、相關日期依當年政府規定於每年開始時，公告同仁周知。\\n三、主管或同仁個人因工作上的需要必須應用此放假日工作者，必須依照延長工作時間申請程序申請延長工作。\\n四、申請延長工作時間作業必須在規定期限內完成。\\n五、本延長工作時間之薪資按日工資再發一日。"},{"score":0.2645357,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \\n \\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}]}')], usage=Usage(requests=1, request_tokens=2116, response_tokens=1072, total_tokens=3188, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 17, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-4NcpuJJt4qXAYQX1UJGD97KYtN6YwS7w'),
#   ModelRequest(parts=[UserPromptPart(content='請假天數限制', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 25, 163959, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='retrieve_fps_rules_db', args='{"query":"請假天數限制"}', tool_call_id='hZFIEtIiHen3WQ41XnrxX3hr0FIlbLWv')], usage=Usage(requests=1, request_tokens=984, response_tokens=50, total_tokens=1034, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 28, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-m6naXDnp6AonrBBERm5gdDDpVIhR31qC'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='retrieve_fps_rules_db', content=[{'score': 0.7, 'text': '一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\n二、生日假於生日當月有效，棄權者不得再補休。\n三、生日假薪資照給。'}, {'score': 0.67383134, 'text': '一、同仁本人生產前後，產假八週(含星期例假日)。\n二、同仁本人妊娠三個月以上流產者，給予產假四星期。(含星期例假日)\n三、妊娠二個月以上未滿三個月流產者，給予產假一星期。(含星期例假日，不給薪)\n四、妊娠未滿二個月流產者，給予產假五日。(含星期例假日，不給薪)\n五、第一項、第二項產假期間薪資，對已任職滿六個月以上同仁，薪資照給，未滿六個月者減半發給。'}, {'score': 0.48483455, 'text': '一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'}, {'score': 0.37600818, 'text': '一、公司原則上以星期日為例假日，星期六為休息日。\n二、例假日不得工作，但是若因天災、事變或突發事件，雇主認有繼續工作之必要時，得停止員工例假日、國定假日、特休期間之假期。但停止假期之工資，應加倍發給，並應於事後補假休息。\n前項停止員工假期，應於事後二十四小時內，詳述理由，報請當地主管機關核備。\n三、例假日工資照給。'}, {'score': 0.3007, 'text': '一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。'}], tool_call_id='hZFIEtIiHen3WQ41XnrxX3hr0FIlbLWv', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 29, 161238, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"response":[{"score":0.7,"text":"一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\\n二、生日假於生日當月有效，棄權者不得再補休。\\n三、生日假薪資照給。"},{"score":0.67383134,"text":"一、同仁本人生產前後，產假八週(含星期例假日)。\\n二、同仁本人妊娠三個月以上流產者，給予產假四星期。(含星期例假日)\\n三、妊娠二個月以上未滿三個月流產者，給予產假一星期。(含星期例假日，不給薪)\\n四、妊娠未滿二個月流產者，給予產假五日。(含星期例假日，不給薪)\\n五、第一項、第二項產假期間薪資，對已任職滿六個月以上同仁，薪資照給，未滿六個月者減半發給。"},{"score":0.48483455,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.37600818,"text":"一、公司原則上以星期日為例假日，星期六為休息日。\\n二、例假日不得工作，但是若因天災、事變或突發事件，雇主認有繼續工作之必要時，得停止員工例假日、國定假日、特休期間之假期。但停止假期之工資，應加倍發給，並應於事後補假休息。\\n前項停止員工假期，應於事後二十四小時內，詳述理由，報請當地主管機關核備。\\n三、例假日工資照給。"},{"score":0.3007,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\\n \\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}]}', tool_call_id='HJmIg0zos2pal0ilJB05d5k2OkdwzNMK')], usage=Usage(requests=1, request_tokens=1971, response_tokens=928, total_tokens=2899, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 4, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-jdbS47NaybD0X6dmQD7PWQk8pN837ujM'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='HJmIg0zos2pal0ilJB05d5k2OkdwzNMK', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 4, 587372, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"response":[{"score":0.7,"text":"一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\\n二、生日假於生日當月有效，棄權者不得再補休。\\n三、生日假薪資照給。"},{"score":0.67383134,"text":"一、同仁本人生產前後，產假八週(含星期例假日)。\\n二、同仁本人妊娠三個月以上流產者，給予產假四星期。(含星期例假日)\\n三、妊娠二個月以上未滿三個月流產者，給予產假一星期。(含星期例假日，不給薪)\\n四、妊娠未滿二個月流產者，給予產假五日。(含星期例假日，不給薪)\\n五、第一項、第二項產假期間薪資，對已任職滿六個月以上同仁，薪資照給，未滿六個月者減半發給。"},{"score":0.48483455,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.37600818,"text":"一、公司原則上以星期日為例假日，星期六為休息日。\\n二、例假日不得工作，但是若因天災、事變或突發事件，雇主認有繼續工作之必要時，得停止員工例假日、國定假日、特休期間之假期。但停止假期之工資，應加倍發給，並應於事後補假休息。\\n前項停止員工假期，應於事後二十四小時內，詳述理由，報請當地主管機關核備。\\n三、例假日工資照給。"},{"score":0.3007,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\\n \\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}]}')], usage=Usage(requests=1, request_tokens=1971, response_tokens=928, total_tokens=2899, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 4, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-jdbS47NaybD0X6dmQD7PWQk8pN837ujM'),
#   ModelRequest(parts=[UserPromptPart(content='特休假規定', timestamp=datetime.datetime(2025, 7, 18, 9, 8, 53, 531519, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='retrieve_fps_rules_db', args='{"query":"特休假規定"}', tool_call_id='sOBHyY0q7bRHTatJqTlr1tOaDrKP8Kpq')], usage=Usage(requests=1, request_tokens=983, response_tokens=49, total_tokens=1032, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 8, 55, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-5k7qg5Km7emB2vMtRsWuUJNEhUkuX8EN'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='retrieve_fps_rules_db', content=[{'score': 0.7, 'text': '此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。'}, {'score': 0.58001995, 'text': '一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。'}, {'score': 0.30635563, 'text': '一、因公司業務需要，而指派特定人員參加考試檢定者，其費用由公司全額支付。\n二、因公司人才培育需求而鼓勵同仁自發性參與特定考試檢定者，依個別鼓勵辦法補助之。\n三、檢定考試完成之後，憑三聯式發票及考試成績單或檢定合格證書提出申請。'}, {'score': 0.3, 'text': '一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\n年資\t特休假日數\n滿6個月~未滿1年\t3天\n滿1年~未滿2年\t7天\n滿2年~未滿3年\t10天\n滿3年~未滿5年\t14天\n滿5年~未滿10年\t15天\n滿10年以上\t每年加一天至30天止\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\n五、特休假期間薪資照給。'}, {'score': 0.28039062, 'text': '同仁年資之採計方式規定如下:\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。'}], tool_call_id='sOBHyY0q7bRHTatJqTlr1tOaDrKP8Kpq', timestamp=datetime.datetime(2025, 7, 18, 9, 8, 56, 176774, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Retrieve relevant documents from the specific vector database. When retrieving from the database, the user's original intent should be preserved as much as possible, and the clarity of the question's meaning should be maintained.\n2. Return all the retrieval results with Reference format."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"response":[{"score":0.7,"text":"此為依據勞動基準法所訂定的最基準工作時間。\\n一、每週工作時數不得超過四十小時。\\n二、每日工作時數為八小時。\\n三、每日工作時間為\\n08:30 開始上班\\n12:00 午休及午餐時間\\n13:00 下午工作時間開始\\n15:00 下午休息時間\\n15:15 繼續工作\\n17:30 下班\\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\\n1.\\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\\n2.\\t調整工作時間。\\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。"},{"score":0.58001995,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.30635563,"text":"一、因公司業務需要，而指派特定人員參加考試檢定者，其費用由公司全額支付。\\n二、因公司人才培育需求而鼓勵同仁自發性參與特定考試檢定者，依個別鼓勵辦法補助之。\\n三、檢定考試完成之後，憑三聯式發票及考試成績單或檢定合格證書提出申請。"},{"score":0.3,"text":"一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\\n年資\\t特休假日數\\n滿6個月~未滿1年\\t3天\\n滿1年~未滿2年\\t7天\\n滿2年~未滿3年\\t10天\\n滿3年~未滿5年\\t14天\\n滿5年~未滿10年\\t15天\\n滿10年以上\\t每年加一天至30天止\\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\\n五、特休假期間薪資照給。"},{"score":0.28039062,"text":"同仁年資之採計方式規定如下:\\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"}]}', tool_call_id='WmWbUwZkR8O0E5kD4sORFE7fnzeDJEX3')], usage=Usage(requests=1, request_tokens=2102, response_tokens=1053, total_tokens=3155, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 34, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-8a9IImlHXbgJpMFerNHLZLRpL7Qh8YIt'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='WmWbUwZkR8O0E5kD4sORFE7fnzeDJEX3', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 34, 868551, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"response":[{"score":0.7,"text":"此為依據勞動基準法所訂定的最基準工作時間。\\n一、每週工作時數不得超過四十小時。\\n二、每日工作時數為八小時。\\n三、每日工作時間為\\n08:30 開始上班\\n12:00 午休及午餐時間\\n13:00 下午工作時間開始\\n15:00 下午休息時間\\n15:15 繼續工作\\n17:30 下班\\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\\n1.\\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\\n2.\\t調整工作時間。\\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。"},{"score":0.58001995,"text":"一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\\n二、薪資項目主要區分為二類\\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\\n主管加給：付與任管理職的同仁的薪資加給稱之。\\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。"},{"score":0.30635563,"text":"一、因公司業務需要，而指派特定人員參加考試檢定者，其費用由公司全額支付。\\n二、因公司人才培育需求而鼓勵同仁自發性參與特定考試檢定者，依個別鼓勵辦法補助之。\\n三、檢定考試完成之後，憑三聯式發票及考試成績單或檢定合格證書提出申請。"},{"score":0.3,"text":"一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\\n年資\\t特休假日數\\n滿6個月~未滿1年\\t3天\\n滿1年~未滿2年\\t7天\\n滿2年~未滿3年\\t10天\\n滿3年~未滿5年\\t14天\\n滿5年~未滿10年\\t15天\\n滿10年以上\\t每年加一天至30天止\\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\\n五、特休假期間薪資照給。"},{"score":0.28039062,"text":"同仁年資之採計方式規定如下:\\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"}]}')], usage=Usage(requests=1, request_tokens=2102, response_tokens=1053, total_tokens=3155, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 34, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-8a9IImlHXbgJpMFerNHLZLRpL7Qh8YIt')],
#  'critic_agent': [ModelRequest(parts=[UserPromptPart(content="The user's query and the retrieved passages are as follows:\n## User Query: 我想要請假，有沒有什麼限制？\n## Retrieved Passages:\n[1] 此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。\n[2] 一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。\n[3] 一、同仁因執行公務中受傷之病假，稱為公傷假。\n二、公傷假之醫療費用，以勞工保險及公司加保之團保負擔之，其餘相關規定及補償辦法比照第八章災害傷病補償及撫卹之規定辦理。\n三、職業災害未認定前，勞工得先請普通傷病假；普通傷病假期滿，得申請留職停薪，如認定結果為職業災害，再以公傷病假處理。\n[4] 一、紀念日，勞動節日及中央主管機關規定應放假之日，是放假日。 \n二、相關日期依當年政府規定於每年開始時，公告同仁周知。\n三、主管或同仁個人因工作上的需要必須應用此放假日工作者，必須依照延長工作時間申請程序申請延長工作。\n四、申請延長工作時間作業必須在規定期限內完成。\n五、本延長工作時間之薪資按日工資再發一日。\n[5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。", timestamp=datetime.datetime(2025, 7, 18, 9, 2, 18, 601147, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Critically evaluate whether the retrieved passages are relevant to the user's query.\n2. Critically evaluate whether the retrieved passages are sufficient to answer the user's query."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"passages":[{"relevant":true,"text":"[5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \\n\\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}],"explanation":"這份文件提供了請假的方法和流程，以及不同天數的請假需要提前多久申請，以及主管的審批權限。雖然其他文件提到了病假等類型，但[5]最完整地回答了使用者關於請假限制的問題。","sufficient":true}', tool_call_id='qkLmCcbvImRwSPMsPPIqCeUOvFh0aW0j')], usage=Usage(requests=1, request_tokens=1403, response_tokens=417, total_tokens=1820, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 35, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-EfDy9FujqoTkZ5ia9bIHKYsOR1Xl9fav'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='qkLmCcbvImRwSPMsPPIqCeUOvFh0aW0j', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 35, 996160, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"passages":[{"relevant":true,"text":"[5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \\n\\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"}],"explanation":"這份文件提供了請假的方法和流程，以及不同天數的請假需要提前多久申請，以及主管的審批權限。雖然其他文件提到了病假等類型，但[5]最完整地回答了使用者關於請假限制的問題。","sufficient":true}')], usage=Usage(requests=1, request_tokens=1403, response_tokens=417, total_tokens=1820, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 35, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-EfDy9FujqoTkZ5ia9bIHKYsOR1Xl9fav'),
#   ModelRequest(parts=[UserPromptPart(content="The user's query and the retrieved passages are as follows:\n## User Query: 我可以請幾天假？\n## Retrieved Passages:\n[1] 一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\n二、生日假於生日當月有效，棄權者不得再補休。\n三、生日假薪資照給。\n[2] 一、同仁本人生產前後，產假八週(含星期例假日)。\n二、同仁本人妊娠三個月以上流產者，給予產假四星期。(含星期例假日)\n三、妊娠二個月以上未滿三個月流產者，給予產假一星期。(含星期例假日，不給薪)\n四、妊娠未滿二個月流產者，給予產假五日。(含星期例假日，不給薪)\n五、第一項、第二項產假期間薪資，對已任職滿六個月以上同仁，薪資照給，未滿六個月者減半發給。\n[3] 一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。\n[4] 一、公司原則上以星期日為例假日，星期六為休息日。\n二、例假日不得工作，但是若因天災、事變或突發事件，雇主認有繼續工作之必要時，得停止員工例假日、國定假日、特休期間之假期。但停止假期之工資，應加倍發給，並應於事後補假休息。\n前項停止員工假期，應於事後二十四小時內，詳述理由，報請當地主管機關核備。\n三、例假日工資照給。\n[5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n \n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。", timestamp=datetime.datetime(2025, 7, 18, 9, 4, 5, 661798, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Critically evaluate whether the retrieved passages are relevant to the user's query.\n2. Critically evaluate whether the retrieved passages are sufficient to answer the user's query."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"passages":[{"relevant":true,"text":"一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\\n二、生日假於生日當月有效，棄權者不得再補休。\\n三、生日假薪資照給。"},{"relevant":true,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。"},{"relevant":true,"text":"請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理"}],"explanation":"根據提供的資料，員工到職當年可請一天生日假。此外，資料也列出了十四種休假種類，並說明了請假天數與核准權限。但要請幾天假，還需要根據具體的休假種類（例如特休假）以及員工的職位和請假原因而定。","sufficient":false}', tool_call_id='hlDe7shgLrkhhD3COPn6F0ahgayZ7Wzw')], usage=Usage(requests=1, request_tokens=1260, response_tokens=401, total_tokens=1661, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 19, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-qMurWA1nn0jKBqfmM7xwe9mTXdUUnSRi'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='hlDe7shgLrkhhD3COPn6F0ahgayZ7Wzw', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 20, 71094, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"passages":[{"relevant":true,"text":"一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\\n二、生日假於生日當月有效，棄權者不得再補休。\\n三、生日假薪資照給。"},{"relevant":true,"text":"一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。"},{"relevant":true,"text":"請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理"}],"explanation":"根據提供的資料，員工到職當年可請一天生日假。此外，資料也列出了十四種休假種類，並說明了請假天數與核准權限。但要請幾天假，還需要根據具體的休假種類（例如特休假）以及員工的職位和請假原因而定。","sufficient":false}')], usage=Usage(requests=1, request_tokens=1260, response_tokens=401, total_tokens=1661, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 19, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-qMurWA1nn0jKBqfmM7xwe9mTXdUUnSRi'),
#   ModelRequest(parts=[UserPromptPart(content="The user's query and the retrieved passages are as follows:\n## User Query: 我想請特休假\n## Retrieved Passages:\n[1] 此為依據勞動基準法所訂定的最基準工作時間。\n一、每週工作時數不得超過四十小時。\n二、每日工作時數為八小時。\n三、每日工作時間為\n08:30 開始上班\n12:00 午休及午餐時間\n13:00 下午工作時間開始\n15:00 下午休息時間\n15:15 繼續工作\n17:30 下班\n子女未滿一歲須員工親自哺乳者，除規定之休息時間外，本公司將每日另給哺乳時間二次，每次以三十分鐘為度，哺乳時間，視為工作時間。\n員工為撫育未滿三歲子女，得請求下列所定事項之一：\n1.\t每天減少工作時間一小時；減少之工作時間，不得請求報酬。\n2.\t調整工作時間。\n員工為前二項哺乳時間、減少或調整工時之請求時，本公司不得拒絕或視為缺勤而影響其全勤獎金、考績或為其他不利之處分。\n[2] 一、薪資採月薪制，破月者薪資以月薪除以30算出日薪資再乘實際工作天數(含工作期間的例假日)。時薪則以日薪除以8計算得之。\n二、薪資項目主要區分為二類\n基本薪資：依同仁所任職務之不同所給予之工作報酬稱之。\n主管加給：付與任管理職的同仁的薪資加給稱之。\n薪資與職務對照表另行訂定，並依當時之物價指數不同而調整。\n[3] 一、因公司業務需要，而指派特定人員參加考試檢定者，其費用由公司全額支付。\n二、因公司人才培育需求而鼓勵同仁自發性參與特定考試檢定者，依個別鼓勵辦法補助之。\n三、檢定考試完成之後，憑三聯式發票及考試成績單或檢定合格證書提出申請。\n[4] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\n年資\t特休假日數\n滿6個月~未滿1年\t3天\n滿1年~未滿2年\t7天\n滿2年~未滿3年\t10天\n滿3年~未滿5年\t14天\n滿5年~未滿10年\t15天\n滿10年以上\t每年加一天至30天止\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\n五、特休假期間薪資照給。\n[5] 同仁年資之採計方式規定如下:\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。", timestamp=datetime.datetime(2025, 7, 18, 9, 9, 35, 979035, tzinfo=datetime.timezone.utc))], instructions="You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Critically evaluate whether the retrieved passages are relevant to the user's query.\n2. Critically evaluate whether the retrieved passages are sufficient to answer the user's query."),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"passages":[{"relevant":true,"text":"一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\\n年資\\t特休假日數\\n滿6個月~未滿1年\\t3天\\n滿1年~未滿2年\\t7天\\n滿2年~未滿3年\\t10天\\n滿3年~未滿5年\\t14天\\n滿5年~未滿10年\\t15天\\n滿10年以上\\t每年加一天至30天止\\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\\n五、特休假期間薪資照給。"},{"relevant":true,"text":"一、同仁年資之採計方式規定如下:\\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"}],"explanation":"這兩段文字直接說明了公司的特休假規定，包括特休假天數的計算方式（依照年資）、未休餘假的處理方式（遞延或結算薪資），以及休假規劃的注意事項。這些資訊對於您請特休假非常有幫助。","sufficient":true}', tool_call_id='3VMpnWg5qmHLZ85f8qt7KeGDbfiPQg08')], usage=Usage(requests=1, request_tokens=1379, response_tokens=567, total_tokens=1946, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 59, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-J7kTUpVvxei5YMJTmyP0EUEDDx3UeMer'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='3VMpnWg5qmHLZ85f8qt7KeGDbfiPQg08', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 59, 504075, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"passages":[{"relevant":true,"text":"一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\\n年資\\t特休假日數\\n滿6個月~未滿1年\\t3天\\n滿1年~未滿2年\\t7天\\n滿2年~未滿3年\\t10天\\n滿3年~未滿5年\\t14天\\n滿5年~未滿10年\\t15天\\n滿10年以上\\t每年加一天至30天止\\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\\n五、特休假期間薪資照給。"},{"relevant":true,"text":"一、同仁年資之採計方式規定如下:\\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"}],"explanation":"這兩段文字直接說明了公司的特休假規定，包括特休假天數的計算方式（依照年資）、未休餘假的處理方式（遞延或結算薪資），以及休假規劃的注意事項。這些資訊對於您請特休假非常有幫助。","sufficient":true}')], usage=Usage(requests=1, request_tokens=1379, response_tokens=567, total_tokens=1946, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 9, 59, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-J7kTUpVvxei5YMJTmyP0EUEDDx3UeMer')],
#  'generator_agent': [ModelRequest(parts=[UserPromptPart(content="The user's query and the retrieved passages are as follows:\n## User Query: 我想要請假，有沒有什麼限制？\n## Relevant Passages:\n[1] [5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。 \n\n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。", timestamp=datetime.datetime(2025, 7, 18, 9, 2, 35, 997251, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Generate a final answer based on the retrieved passages.\n2. If the retrieved passages are insufficient, ask follow-up questions to gather more information.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"final_answer":"根據公司規定，請假種類共有十四種，包含特休假、生日假等等。請假方式需要事先填寫請假單或口頭敘明理由經核定。請假天數不同，核准主管權限及事前天數也不同：\\n\\n*   0-5天：三天前，部門主管核准\\n*   5-10天：一週前，處級主管核准\\n*   超過10天：兩週前，業務/事業群總經理核准\\n\\n如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。","reference":["[1] [5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\\n\\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"]}', tool_call_id='5hhn5xmo9xMXc8GefYrG6ZZ05UzH8lQ4')], usage=Usage(requests=1, request_tokens=670, response_tokens=513, total_tokens=1183, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 54, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-WxWHr22Oyr8Vu7dnQF7dHNmsiThvaqN9'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='5hhn5xmo9xMXc8GefYrG6ZZ05UzH8lQ4', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 54, 474425, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"final_answer":"根據公司規定，請假種類共有十四種，包含特休假、生日假等等。請假方式需要事先填寫請假單或口頭敘明理由經核定。請假天數不同，核准主管權限及事前天數也不同：\\n\\n*   0-5天：三天前，部門主管核准\\n*   5-10天：一週前，處級主管核准\\n*   超過10天：兩週前，業務/事業群總經理核准\\n\\n如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。","reference":["[1] [5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\\n\\n請假天數，核准主管權限及事前天數辦法如下：\\n請假天數\\t事前天數\\t核准主管權限\\n0<天數≦5\\t三天前\\t部門主管\\n5<天數≦10\\t一週前\\t處級主管\\n天數>10\\t兩週前\\t業務/事業群總經理\\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。"]}')], usage=Usage(requests=1, request_tokens=670, response_tokens=513, total_tokens=1183, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 54, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-WxWHr22Oyr8Vu7dnQF7dHNmsiThvaqN9'),
#   ModelRequest(parts=[UserPromptPart(content="The user's query and the retrieved passages are as follows:\n## User Query: 我想請特休假\n## Relevant Passages:\n[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假:\n年資\t特休假日數\n滿6個月~未滿1年\t3天\n滿1年~未滿2年\t7天\n滿2年~未滿3年\t10天\n滿3年~未滿5年\t14天\n滿5年~未滿10年\t15天\n滿10年以上\t每年加一天至30天止\n二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。\n三、如特休年度屆滿或終止契約而應休未休之日數，將依原始年度之薪資結算給同仁。\n四、同仁於年度開始時應做休假規劃，以期達到身心舒展的目的。休假之規劃應與主管取得溝通，以免造成工作安排之困擾。\n五、特休假期間薪資照給。\n[2] 一、同仁年資之採計方式規定如下:\n一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。\n二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。", timestamp=datetime.datetime(2025, 7, 18, 9, 9, 59, 505578, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Generate a final answer based on the retrieved passages.\n2. If the retrieved passages are insufficient, ask follow-up questions to gather more information.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"final_answer":"您好，根據公司規定，特休假天數依您的年資而定：\\n\\n*   滿6個月~未滿1年：3天\\n*   滿1年~未滿2年：7天\\n*   滿2年~未滿3年：10天\\n*   滿3年~未滿5年：14天\\n*   滿5年~未滿10年：15天\\n*   滿10年以上：每年加一天至30天止\\n\\n請您確認您的年資，以便計算您的特休天數。另外，請您在年度開始時做休假規劃，並與主管溝通，以確保工作順利進行。未休的特休假可以選擇遞延一年或結算薪資。","reference":["[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\\t特休假日數 滿6個月~未滿1年\\t3天 滿1年~未滿2年\\t7天 滿2年~未滿3年\\t10天 滿3年~未滿5年\\t14天 滿5年~未滿10年\\t15天 滿10年以上\\t每年加一天至30天止 二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。","[2] 一、同仁年資之採計方式規定如下: 一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"]}', tool_call_id='ldRh7nG8GD2rRU5454kcnKkCRXmeZli7')], usage=Usage(requests=1, request_tokens=798, response_tokens=552, total_tokens=1350, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 18, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-30HKSjIPC6RrDt36mU6fTcJHn6awC5vU'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='ldRh7nG8GD2rRU5454kcnKkCRXmeZli7', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 18, 552351, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"final_answer":"您好，根據公司規定，特休假天數依您的年資而定：\\n\\n*   滿6個月~未滿1年：3天\\n*   滿1年~未滿2年：7天\\n*   滿2年~未滿3年：10天\\n*   滿3年~未滿5年：14天\\n*   滿5年~未滿10年：15天\\n*   滿10年以上：每年加一天至30天止\\n\\n請您確認您的年資，以便計算您的特休天數。另外，請您在年度開始時做休假規劃，並與主管溝通，以確保工作順利進行。未休的特休假可以選擇遞延一年或結算薪資。","reference":["[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\\t特休假日數 滿6個月~未滿1年\\t3天 滿1年~未滿2年\\t7天 滿2年~未滿3年\\t10天 滿3年~未滿5年\\t14天 滿5年~未滿10年\\t15天 滿10年以上\\t每年加一天至30天止 二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。","[2] 一、同仁年資之採計方式規定如下: 一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。"]}')], usage=Usage(requests=1, request_tokens=798, response_tokens=552, total_tokens=1350, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 18, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-30HKSjIPC6RrDt36mU6fTcJHn6awC5vU')],
#  'assistant_agent': [ModelRequest(parts=[UserPromptPart(content='我想要請假，有沒有什麼限制？', timestamp=datetime.datetime(2025, 7, 18, 9, 1, 20, 884485, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='rag', args='{"query":"請假規定"}', tool_call_id='9nwch4YZAs59EH6oYMpTLnVUti6CCo9L')], usage=Usage(requests=1, request_tokens=538, response_tokens=42, total_tokens=580, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 1, 22, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-R6wmdWU9x92d5aHzF31j8jQ3lyB4fvfs'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='rag', content=RAGFormat(reference=['[1] [5] 一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。\n二、請假方法：員工因故必須請假者，應事先填寫請假單或口頭敘明理由經核定後方可離開工作崗位或不出勤。\n\n請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理\n三、臨時狀況：同仁因突發事件或生病必須於當日請假者，得於當日10:00前以電話向主管報備，並於事後補辦請假手續。\n四、同仁未依規定辦理請假手續者，事後又不補辦請假手續並說明原因者，視同曠職。'], final_answer='根據公司規定，請假種類共有十四種，包含特休假、生日假等等。請假方式需要事先填寫請假單或口頭敘明理由經核定。請假天數不同，核准主管權限及事前天數也不同：\n\n*   0-5天：三天前，部門主管核准\n*   5-10天：一週前，處級主管核准\n*   超過10天：兩週前，業務/事業群總經理核准\n\n如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。'), tool_call_id='9nwch4YZAs59EH6oYMpTLnVUti6CCo9L', timestamp=datetime.datetime(2025, 7, 18, 9, 2, 54, 475223, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[TextPart(content='好的，公司請假規定如下：\n\n一、休假種類共有十四種，包含特休假、生日假等等。\n二、請假方式需要事先填寫請假單或口頭敘明理由經核定。\n三、請假天數不同，核准主管權限及事前天數也不同：\n\n* 0-5天：三天前，部門主管核准\n* 5-10天：一週前，處級主管核准\n* 超過10天：兩週前，業務/事業群總經理核准\n\n四、如果遇到突發狀況或生病需要當日請假，需在上午10點前電話報備，並事後補辦手續。未依規定請假且未補辦手續將視同曠職。\n\n請問您還有其他想了解的嗎？')], usage=Usage(requests=1, request_tokens=1153, response_tokens=212, total_tokens=1365, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 1, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-GiKxlZ0XiagYAPYhxMwBDrblzVaYTjPL'),
#   ModelRequest(parts=[UserPromptPart(content='我可以請幾天假？', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 12, 937113, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='rag', args='{"query":"請假天數限制"}', tool_call_id='1YxdAVVVk4fH2gkmFaSH8lKLGVNILWTQ')], usage=Usage(requests=1, request_tokens=1357, response_tokens=44, total_tokens=1401, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 3, 15, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-2t1djvG6GUW2sZc4lvJtoIEB7kqKUgz0'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='rag', content=Criticism(passages=[ReferenceWithCriticism(relevant=True, text='一、同仁到職當年度即享有一天生日假，生日當月可擇一日請(放)生日假；請假之最小單位為一天。\n二、生日假於生日當月有效，棄權者不得再補休。\n三、生日假薪資照給。'), ReferenceWithCriticism(relevant=True, text='一、休假種類包含：特休假、生日假、普通傷病假、事假、家庭照顧假、婚假、喪假、產假、陪產假、產檢假、安胎假、公傷假、生理假、公假共十四種。'), ReferenceWithCriticism(relevant=True, text='請假天數，核准主管權限及事前天數辦法如下：\n請假天數\t事前天數\t核准主管權限\n0<天數≦5\t三天前\t部門主管\n5<天數≦10\t一週前\t處級主管\n天數>10\t兩週前\t業務/事業群總經理')], explanation='根據提供的資料，員工到職當年可請一天生日假。此外，資料也列出了十四種休假種類，並說明了請假天數與核准權限。但要請幾天假，還需要根據具體的休假種類（例如特休假）以及員工的職位和請假原因而定。', sufficient=False), tool_call_id='1YxdAVVVk4fH2gkmFaSH8lKLGVNILWTQ', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 20, 71696, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[TextPart(content='您可以請的假天數取決於您要請哪一種假。根據公司規定：\n\n*   到職當年可以請一天生日假。\n*   其他休假種類，例如特休假、事假等等，請假天數沒有明確限制，但需要根據您的職位和請假原因，並事先向主管申請。具體天數需要依照公司請假規定（0-5天、5-10天、超過10天）來決定。\n\n請問您想請哪一種假呢？這樣我才能更準確地告訴您。')], usage=Usage(requests=1, request_tokens=1827, response_tokens=139, total_tokens=1966, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 4, 25, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-neDB0r43IU8R4BZbR94LAOxdEzIpsjbI'),
#   ModelRequest(parts=[UserPromptPart(content='我想請特休假', timestamp=datetime.datetime(2025, 7, 18, 9, 8, 39, 21982, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='rag', args='{"query":"特休假規定"}', tool_call_id='h1yykQR0hfYMRrM2hGlZnPBIOV9qFbjz')], usage=Usage(requests=1, request_tokens=1966, response_tokens=43, total_tokens=2009, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 8, 41, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-iDBbMUNAGeSwnHTf65DNcKa7PufKQ3f5'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='rag', content=RAGFormat(reference=['[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\t特休假日數 滿6個月~未滿1年\t3天 滿1年~未滿2年\t7天 滿2年~未滿3年\t10天 滿3年~未滿5年\t14天 滿5年~未滿10年\t15天 滿10年以上\t每年加一天至30天止 二、因年度終結而應休未休之日數，經勞資雙方協商，同仁可選擇全數遞延一年或結算薪資；遞延者，至多以遞延一年為限；若員工未於期限內回覆者，將一律結算薪資予同仁。', '[2] 一、同仁年資之採計方式規定如下: 一、實際年資：同仁享用公司所提供之權利、義務(本手冊所載明者)與年資有關時，除非特別指明（如休假年資），其他之計算方式均按實際工作年資計算，即自到職日起至次年的到職日之前一日為一年，享有該累積年資的相關權利。二、休假年資：休假的實施以休假年資起算日為主，採週年制計算特休。'], final_answer='您好，根據公司規定，特休假天數依您的年資而定：\n\n*   滿6個月~未滿1年：3天\n*   滿1年~未滿2年：7天\n*   滿2年~未滿3年：10天\n*   滿3年~未滿5年：14天\n*   滿5年~未滿10年：15天\n*   滿10年以上：每年加一天至30天止\n\n請您確認您的年資，以便計算您的特休天數。另外，請您在年度開始時做休假規劃，並與主管溝通，以確保工作順利進行。未休的特休假可以選擇遞延一年或結算薪資。'), tool_call_id='h1yykQR0hfYMRrM2hGlZnPBIOV9qFbjz', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 18, 552990, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[TextPart(content='您好，根據公司規定，特休假天數依您的年資而定：\n\n*   滿6個月~未滿1年：3天\n*   滿1年~未滿2年：7天\n*   滿2年~未滿3年：10天\n*   滿3年~未滿5年：14天\n*   滿5年~未滿10年：15天\n*   滿10年以上：每年加一天至30天止\n\n請您確認您的年資，以便計算您的特休天數。另外，未休的特休假可以選擇遞延一年或結算薪資。')], usage=Usage(requests=1, request_tokens=2619, response_tokens=165, total_tokens=2784, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 27, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-tK7JHm1k9UrmJMH3vV9DzbPyskHnVksU'),
#   ModelRequest(parts=[UserPromptPart(content='我目前工作滿一年了', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 30, 266720, tzinfo=datetime.timezone.utc))], instructions='You are a helpful and intelligent assistant. The user you are helping speaks Traditional Chinese and comes from Taiwan, so in most cases, you should respond in Traditional Chinese. \nBehavior Rules: \n1. Direct Answering: If the question is clear and within your knowledge, answer directly.\n2. Clarification: If the question is vague or unclear, ask clarifying questions to understand the user’s intent before responding.\n3. Retrieval: If the question requires specialized or external knowledge, use the `rag` to obtain an answer based on relevant information retrieved from the database. Return the result with `RAGFormat` format.'),
#   ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"final_answer":"您好，由於您目前工作滿一年了，根據公司規定，您今年可以請7天的特休假。","reference":["[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\\\\t特休假日數 滿6個月~未滿1年\\\\t3天 滿1年~未滿2年\\\\t7天 滿2年~未滿3年\\\\t10天 滿3年~未滿5年\\\\t14天 滿5年~未滿10年\\\\t15天 滿10年以上\\\\t每年加一天至30天止"]}', tool_call_id='TkEg0fnyzDPDCzZ0eKXq5Jq6844bFT7R')], usage=Usage(requests=1, request_tokens=2779, response_tokens=198, total_tokens=2977, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 38, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-493NhZqddAot7YTvfcS9De0dhAtcWBKy'),
#   ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='TkEg0fnyzDPDCzZ0eKXq5Jq6844bFT7R', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 38, 998835, tzinfo=datetime.timezone.utc))]),
#   ModelResponse(parts=[TextPart(content='{"final_answer":"您好，由於您目前工作滿一年了，根據公司規定，您今年可以請7天的特休假。","reference":["[1] 一、同仁於本公司繼續工作滿一定期間者，每年依下列規定給與特別休假: 年資\\\\t特休假日數 滿6個月~未滿1年\\\\t3天 滿1年~未滿2年\\\\t7天 滿2年~未滿3年\\\\t10天 滿3年~未滿5年\\\\t14天 滿5年~未滿10年\\\\t15天 滿10年以上\\\\t每年加一天至30天止"]}')], usage=Usage(requests=1, request_tokens=2779, response_tokens=198, total_tokens=2977, details={}), model_name='gemma3:27b-it-qat', timestamp=datetime.datetime(2025, 7, 18, 9, 10, 38, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-493NhZqddAot7YTvfcS9De0dhAtcWBKy')]}
